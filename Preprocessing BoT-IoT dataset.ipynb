# %%
import pandas
import random
import ipaddress

# %%
filename = "UNSW_2018_IoT_Botnet_Final_10_Best.csv"
df = pandas.read_csv(filename)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (4,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df=df.drop(['category', 'subcategory'], axis='columns')

# %%
df.head()
# Out:
#    index  pkSeqID proto            saddr  sport            daddr dport  seq  \
# 0      0        1   tcp  192.168.100.147  49960    192.168.100.7    80    9
# 1      1        2   arp    192.168.100.7     -1  192.168.100.147    -1   10
# 2      2        3   tcp  192.168.100.147  49962    192.168.100.7    80   11
# 3      3        4   tcp  192.168.100.147  49964    192.168.100.7    80   12
# 4      4        5   tcp  192.168.100.147  49966    192.168.100.7    80   13
#
#      stddev  N_IN_Conn_P_SrcIP       min  state_number      mean  \
# 0  0.068909                 75  0.000000             1  0.068909
# 1  0.000000                  2  0.000131             2  0.000131
# 2  0.064494                 75  0.000000             1  0.064494
# 3  0.064189                 75  0.000000             1  0.064189
# 4  0.063887                 75  0.000000             1  0.063887
#
#    N_IN_Conn_P_DstIP      drate     srate       max  attack
# ...

# %%
df.dtypes
# Out:
# index                  int64
# pkSeqID                int64
# proto                 object
# saddr                 object
# sport                 object
# daddr                 object
# dport                 object
# seq                    int64
# stddev               float64
# N_IN_Conn_P_SrcIP      int64
# min                  float64
# state_number           int64
# mean                 float64
# N_IN_Conn_P_DstIP      int64
# drate                float64
# srate                float64
# max                  float64
# attack                 int64
# dtype: object

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()
# Out:
#   proto            saddr  sport            daddr dport
# 0   tcp  192.168.100.147  49960    192.168.100.7    80
# 1   arp    192.168.100.7     -1  192.168.100.147    -1
# 2   tcp  192.168.100.147  49962    192.168.100.7    80
# 3   tcp  192.168.100.147  49964    192.168.100.7    80
# 4   tcp  192.168.100.147  49966    192.168.100.7    80

# %%
obj_df[obj_df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [proto, saddr, sport, daddr, dport]
# Index: []

# %%
obj_df["proto"].value_counts()
# Out:
# udp          1996437
# tcp          1662812
# icmp            9052
# arp              213
# ipv6-icmp          8
# Name: proto, dtype: int64

# %%
cleanup_nums = {"proto":     {"udp": 1, "tcp": 2,"icmp": 3,"arp": 4,"ipv6-icmp": 5}}

# %%
df.replace(cleanup_nums, inplace=True)
df.head()
# Out:
#    index  pkSeqID  proto            saddr  sport            daddr dport  seq  \
# 0      0        1      2  192.168.100.147  49960    192.168.100.7    80    9
# 1      1        2      4    192.168.100.7     -1  192.168.100.147    -1   10
# 2      2        3      2  192.168.100.147  49962    192.168.100.7    80   11
# 3      3        4      2  192.168.100.147  49964    192.168.100.7    80   12
# 4      4        5      2  192.168.100.147  49966    192.168.100.7    80   13
#
#      stddev  N_IN_Conn_P_SrcIP       min  state_number      mean  \
# 0  0.068909                 75  0.000000             1  0.068909
# 1  0.000000                  2  0.000131             2  0.000131
# 2  0.064494                 75  0.000000             1  0.064494
# 3  0.064189                 75  0.000000             1  0.064189
# 4  0.063887                 75  0.000000             1  0.063887
#
#    N_IN_Conn_P_DstIP      drate     srate       max  attack
# ...

# %%
df.dtypes
# Out:
# index                  int64
# pkSeqID                int64
# proto                  int64
# saddr                 object
# sport                 object
# daddr                 object
# dport                 object
# seq                    int64
# stddev               float64
# N_IN_Conn_P_SrcIP      int64
# min                  float64
# state_number           int64
# mean                 float64
# N_IN_Conn_P_DstIP      int64
# drate                float64
# srate                float64
# max                  float64
# attack                 int64
# dtype: object

# %%
obj_df["sport"].value_counts()

# %%
cleanup_nums = {"sport":     {"0x0303": 771, "0x0008": 8,"0x0011": 17,"0x000d": 13}}

# %%
df.replace(cleanup_nums, inplace=True)
df.head()
# Out:
#    index  pkSeqID  proto            saddr  sport            daddr dport  seq  \
# 0      0        1      2  192.168.100.147  49960    192.168.100.7    80    9
# 1      1        2      4    192.168.100.7     -1  192.168.100.147    -1   10
# 2      2        3      2  192.168.100.147  49962    192.168.100.7    80   11
# 3      3        4      2  192.168.100.147  49964    192.168.100.7    80   12
# 4      4        5      2  192.168.100.147  49966    192.168.100.7    80   13
#
#      stddev  N_IN_Conn_P_SrcIP       min  state_number      mean  \
# 0  0.068909                 75  0.000000             1  0.068909
# 1  0.000000                  2  0.000131             2  0.000131
# 2  0.064494                 75  0.000000             1  0.064494
# 3  0.064189                 75  0.000000             1  0.064189
# 4  0.063887                 75  0.000000             1  0.063887
#
#    N_IN_Conn_P_DstIP      drate     srate       max  attack
# ...

# %%
b=obj_df["sport"].value_counts()
# Out:
# 0x0303    8950
# 80        3985
# 2290      1045
# 2456      1043
# 2969      1041
#           ...
# 29486        4
# 29522        4
# 29625        4
# 29511        4
# 29514        4
# Name: sport, Length: 131078, dtype: int64

# %%
for i in range(len(df)):
    df.loc[i,'saddr']=int(ipaddress.IPv4Address(df.loc[i,'saddr'])) 
    df.loc[i,'daddr']=int(ipaddress.IPv4Address(df.loc[i,'daddr']))

# %%
df.head()

# %%
obj_df["saddr"].value_counts()

# %%
obj_df = df.select_dtypes(include=['object']).copy()
obj_df.head()

# %%
df.to_csv('FORMAT_UNSW_2018_IoT_Botnet_Final_10_Best.csv')

# %%
int(ipaddress.IPv6Address('fe80::250:56ff:febe:bf1a'))

# %%
sport_df=obj_df["sport"]

# %%
cleanup_nums = {"sport":     {"0x0303": 771, "0x0008": 8,"0x0011": 17,"0x000d": 13}}

# %%
b.to_csv('test1.csv')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   """Entry point for launching an IPython kernel.
